# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Indian automoble buying behavour study 1.0.csv")
df
# Out:
#     Age Profession Marrital Status      Education  No of Dependents  \
# 0    27   Salaried          Single  Post Graduate                 0
# 1    35   Salaried         Married  Post Graduate                 2
# 2    45   Business         Married       Graduate                 4
# 3    41   Business         Married  Post Graduate                 3
# 4    31   Salaried         Married  Post Graduate                 2
# ..  ...        ...             ...            ...               ...
# 94   27   Business          Single       Graduate                 0
# 95   50   Salaried         Married  Post Graduate                 3
# 96   51   Business         Married       Graduate                 2
# 97   51   Salaried         Married  Post Graduate                 2
# 98   51   Salaried         Married  Post Graduate                 2
#
#    Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# ...

# %% [markdown]
# ###### Analyze age groups interested in EVs.

# %%
df["Age"].value_counts()
# Out:
# 36    13
# 35    10
# 31     8
# 41     7
# 34     7
# 27     6
# 37     6
# 42     5
# 30     5
# 39     4
# 44     4
# 29     4
# 51     3
# 49     3
# 28     3
# 43     2
# 33     2
# 32     2
# 45     2
# 46     1
# 50     1
# 26     1
# Name: Age, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='Age', bins=40, kde=True, color='skyblue')
plt.title('Demographic Segmentation - Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [raw]
# This suggests that the age group between 30 and 40 years old is more likely to be interested in EVs.

# %% [markdown]
# ###### Explore professions of potential EV buyers

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Profession', palette='viridis')
plt.title('Psychographic Segmentation - Profession')
plt.xlabel('Profession')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# The majority of potential customers have salaried professions, with a significant number engaged in business.

# %% [markdown]
# ###### Analyze the behavior of individuals with respect to personal loans and house loans

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Personal loan', hue='House Loan')
plt.title('Behavioral Segmentation - Personal Loan vs. House Loan')
plt.xlabel('Personal Loan')
plt.ylabel('Count')
plt.show()

# %% [raw]
# There is a mix of behavior regarding personal loans and house loans, which may indicate diverse financial backgrounds among potential EV buyers

# %% [markdown]
# ###### Age vs. Salary

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Salary', data=df)
plt.title('Age vs. Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %% [raw]
# There doesn't seem to be a strong linear relationship between age and salary. However, we can see that most customers with higher salaries are in the 30-40 age group.

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Profession', hue='Personal loan', data=df)
plt.title('Profession vs. Personal Loan')
plt.xlabel('Profession')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Salaried professionals tend to have a higher likelihood of taking personal loans compared to business professionals.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Education', y='No of Dependents', hue='House Loan', data=df)
plt.title('Education, No of Dependents, and House Loan')
plt.xlabel('Education')
plt.ylabel('No of Dependents')
plt.show()

# %% [markdown]
# ###### the distribution of car makes among different professions

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Profession', hue='Make', data=df)
plt.title('Profession vs. Make')
plt.xlabel('Profession')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Make')
plt.show()

# %% [raw]
# Salaried professionals have a higher preference for 'Baleno' and 'i20' cars.
# Business professionals have a higher preference for 'Ciaz,' 'Verna,' and 'SUV' cars.

# %% [markdown]
# ###### the distribution of car prices for each make.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Make', y='Price', data=df)
plt.title('Make vs. Price')
plt.xlabel('Make')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# 'Luxury' cars tend to have the highest prices, followed by 'SUV' and 'Creata.'
# 'i20' and 'Baleno' cars generally have lower prices compared to other makes.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Profession', y='Price', data=df)
plt.title('Profession vs. Price')
plt.xlabel('Profession')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Business professionals tend to purchase higher-priced cars on average compared to salaried professionals.
# Salaried professionals typically buy cars across a wider price range

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Education', y='Salary', data=df)
plt.title('Education vs. Salary')
plt.xlabel('Education')
plt.ylabel('Salary')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Post-Graduate individuals tend to have higher salary ranges compared to Graduates.
#
# Graduates also have a wide range of salaries, but the median salary appears to be lower than that of Post-Graduates

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Education', hue='Make', data=df)
plt.title('Education vs. Make')
plt.xlabel('Education')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Make', loc='upper right', bbox_to_anchor=(1.25, 1))
plt.show()

# %% [raw]
# Individuals with a 'Graduate' education level appear to have a preference for 'Baleno' and 'Ciaz' vehicles.
#
# 'Post Graduate' individuals also prefer 'Baleno' and 'Ciaz' vehicles, but there is a relatively higher preference for 'i20' compared to Graduates.
#
# 'i20' seems to be a popular choice across different education levels, but it's particularly preferred by Post Graduates.

# %%
numerical_cols = ['Age', 'Salary', 'Total Salary']

# Create a pairplot
sns.set(style="ticks")
sns.pairplot(df, vars=numerical_cols, hue='Make', diag_kind='kde', markers='o', palette='husl')
plt.suptitle('Multivariate Analysis of Age, Salary, and Total Salary by Make', y=1.02)
plt.show()

# %% [raw]
# 'i20' and 'Ciaz' are popular makes across a wide range of age groups and salary levels. 'i20' has a broader distribution of age groups compared to 'Ciaz.'
#
# 'SUV' and 'Verna' are more common among individuals with higher salaries and older age groups.
#
# 'Baleno' is prevalent in various age groups and has a diverse distribution concerning salary and total salary.
#
# 'City' is associated with a relatively broader age range and varying salary levels.
#
# 'Creata' is most common among middle-aged individuals with moderate to high salaries.

# %% [markdown]
# ### Conclusions

# %% [raw]
# 1] The age group between 30 and 40 years old is more likely to be interested in EVs.
# 2] The majority of potential customers have salaried professions, with a significant number engaged in    business.
# 3] There is a mix of behavior regarding personal loans and house loans, which may indicate diverse        financial backgrounds among potential EV buyers
# 4] Salaried professionals have a higher preference for 'Baleno' and 'i20' cars.
#    Business professionals have a higher preference for 'Ciaz,' 'Verna,' and 'SUV' cars.
# 5] 'Luxury' cars tend to have the highest prices, followed by 'SUV' and 'Creata.'
#    'i20' and 'Baleno' cars generally have lower prices compared to other makes.
# 6] Business professionals tend to purchase higher-priced cars on average compared to salaried            professionals.Salaried professionals typically buy cars across a wider price range
# 7] Post-Graduate individuals tend to have higher salary ranges compared to Graduates.Graduates also      have a wide range of salaries, but the median salary appears to be lower than that of Post            Graduates
# 8] 'i20' and 'Ciaz' are popular makes across a wide range of age groups and salary levels. 'i20' has a     broader distribution of age groups compared to 'Ciaz.''SUV' and 'Verna' are more common among         individuals with higher salaries and older age groups. 'Baleno' is prevalent in various age groups     and has a diverse distribution concerning salary and total salary.'City' is associated with a         relatively broader age range and varying salary levels.'Creata' is most common among middle-aged       individuals with moderate to high salaries.
